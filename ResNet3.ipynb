# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Conv2D,Flatten,Dense,Activation,Add,BatchNormalization,MaxPooling2D,AveragePooling2D,Input,ZeroPadding2D
from keras.initializers import glorot_uniform
from keras.models import Model
import keras
from keras.regularizers import l2
(X_train,y_train),(X_test,y_test)=keras.datasets.cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 12s 0us/step

# %%
def identity_block(X,f,filters):
    
    X_temp = X
    F1,F2 = filters
    
    X = Conv2D(F1,(f,f), strides=(1,1),padding='same',kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X = Conv2D(F2,(f,f), strides=(1,1), padding="same", kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X)
    X=BatchNormalization(axis=3)(X)
    
    X=Add()([X,X_temp])
    X=Activation('relu')(X)
    
    return X

# %%
def conv_block(X,f,filters,s):
    X_temp = X
    F1,F2 = filters
    
    X_temp=Conv2D(F2,(1,1), strides=(s,s), padding="same", kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X_temp)
    X_temp=BatchNormalization(axis=3)(X_temp)
    
    X = Conv2D(F1,(f,f), strides=(s,s),padding='same',kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    
    X = Conv2D(F2,(f,f), strides=(1,1), padding="same", kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X)
    X=BatchNormalization(axis=3)(X)
    
    X=Add()([X,X_temp])
    X=Activation('relu')(X)
    
    return X

# %%
def ModelCustom(input_shape,classes):
    
    X_input=Input(input_shape)
    X=ZeroPadding2D((1,1))(X_input)
    X=Conv2D(32,(3,3), strides=(1,1), kernel_initializer='he_normal',kernel_regularizer=l2(1e-4))(X)
    X=BatchNormalization(axis=3)(X)
    X=Activation('relu')(X)
    #X=MaxPooling2D((3,3),strides=(2,2))(X)
    
    X=conv_block(X,3,(32,32),1)
    X=identity_block(X,3,(32,32))
    X=identity_block(X,3,(32,32))
    X=identity_block(X,3,(32,32))
    
    X=conv_block(X,3,(64,64),2)
    X=identity_block(X,3,(64,64))
    X=identity_block(X,3,(64,64))
    X=identity_block(X,3,(64,64))
    
    X=conv_block(X,3,(128,128),2)
    X=identity_block(X,3,(128,128))
    X=identity_block(X,3,(128,128))
    X=identity_block(X,3,(128,128))
    
    #X=conv_block(X,3,(256,256),2)
    #X=identity_block(X,3,(256,256))
    
    
    #X=conv_block(X,3,(512,512),2)    #commented to reduce params
    #X=identity_block(X,3,(512,512))  # commented out to reduce params
    
    
    X = AveragePooling2D((8, 8))(X)
    
    X = Flatten()(X)
    
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(X)
    
    model=Model(inputs = X_input, outputs = X, name='ResNet34')
    
    return model

# %%
model = ModelCustom((32,32,3),10)

# %%
model.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 34, 34, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   896         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           batch_normalization_4[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           batch_normalization_6[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   9248        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32)   0           batch_normalization_8[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 32)   0           batch_normalization_10[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   18496       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   2112        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           batch_normalization_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 64)   0           batch_normalization_15[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 64)   0           batch_normalization_17[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 64)   0           batch_normalization_19[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    73856       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 128)    512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    147584      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    8320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 128)    0           batch_normalization_22[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 128)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 128)    512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    147584      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 128)    512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           batch_normalization_24[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 128)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    147584      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 128)    512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    147584      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           batch_normalization_26[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 128)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    147584      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 128)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 128)    512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           batch_normalization_28[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           add_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 128)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           1290        flatten_1[0][0]
# ==================================================================================================
# Total params: 1,479,786
# Trainable params: 1,475,690
# Non-trainable params: 4,096
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
image_gen= keras.preprocessing.image.ImageDataGenerator( 
    horizontal_flip=True,
    zca_epsilon=1e-06,
    fill_mode="nearest",
    width_shift_range=0.1,
    height_shift_range=0.1)

image_gen.fit(X_train)

# %%
model.fit_generator(image_gen.flow(X_train, y_train, batch_size=128),
                        validation_data=(X_test, y_test),
                        epochs=30,workers=4)
# Out:
# Epoch 1/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4655 - accuracy: 0.9169 - val_loss: 0.9142 - val_accuracy: 0.8099
# Epoch 2/30
# 391/391 [==============================] - 138s 352ms/step - loss: 0.4603 - accuracy: 0.9191 - val_loss: 0.8010 - val_accuracy: 0.8253
# Epoch 3/30
# 391/391 [==============================] - 138s 352ms/step - loss: 0.4504 - accuracy: 0.9228 - val_loss: 0.9681 - val_accuracy: 0.8022
# Epoch 4/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4538 - accuracy: 0.9206 - val_loss: 0.8305 - val_accuracy: 0.8173
# Epoch 5/30
# 391/391 [==============================] - 138s 352ms/step - loss: 0.4481 - accuracy: 0.9230 - val_loss: 0.7246 - val_accuracy: 0.8427
# Epoch 6/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4513 - accuracy: 0.9229 - val_loss: 0.8105 - val_accuracy: 0.8259
# Epoch 7/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4391 - accuracy: 0.9256 - val_loss: 0.8628 - val_accuracy: 0.8184
# Epoch 8/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4423 - accuracy: 0.9258 - val_loss: 0.6784 - val_accuracy: 0.8550
# Epoch 9/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4433 - accuracy: 0.9262 - val_loss: 0.7427 - val_accuracy: 0.8431
# Epoch 10/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.4318 - accuracy: 0.9284 - val_loss: 1.0235 - val_accuracy: 0.7913
# Epoch 11/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4337 - accuracy: 0.9283 - val_loss: 0.7342 - val_accuracy: 0.8410
# Epoch 12/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4299 - accuracy: 0.9286 - val_loss: 0.7693 - val_accuracy: 0.8362
# Epoch 13/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4343 - accuracy: 0.9278 - val_loss: 0.8024 - val_accuracy: 0.8305
# Epoch 14/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4227 - accuracy: 0.9315 - val_loss: 0.9067 - val_accuracy: 0.8132
# Epoch 15/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4250 - accuracy: 0.9303 - val_loss: 0.7416 - val_accuracy: 0.8403
# Epoch 16/30
# 391/391 [==============================] - 139s 354ms/step - loss: 0.4204 - accuracy: 0.9328 - val_loss: 0.7576 - val_accuracy: 0.8353
# Epoch 17/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4239 - accuracy: 0.9315 - val_loss: 0.8633 - val_accuracy: 0.8281
# Epoch 18/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4211 - accuracy: 0.9324 - val_loss: 0.8476 - val_accuracy: 0.8182
# Epoch 19/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4102 - accuracy: 0.9356 - val_loss: 0.8571 - val_accuracy: 0.8263
# Epoch 20/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4169 - accuracy: 0.9327 - val_loss: 0.7562 - val_accuracy: 0.8447
# Epoch 21/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4108 - accuracy: 0.9347 - val_loss: 0.8902 - val_accuracy: 0.8128
# Epoch 22/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4127 - accuracy: 0.9343 - val_loss: 0.7727 - val_accuracy: 0.8325
# Epoch 23/30
# 391/391 [==============================] - 139s 356ms/step - loss: 0.4038 - accuracy: 0.9387 - val_loss: 0.6214 - val_accuracy: 0.8788
# Epoch 24/30
# 391/391 [==============================] - 138s 353ms/step - loss: 0.4101 - accuracy: 0.9356 - val_loss: 0.6616 - val_accuracy: 0.8688
# Epoch 25/30
# 391/391 [==============================] - 138s 354ms/step - loss: 0.4068 - accuracy: 0.9360 - val_loss: 0.7698 - val_accuracy: 0.8352
# Epoch 26/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.4055 - accuracy: 0.9380 - val_loss: 0.7232 - val_accuracy: 0.8594
# Epoch 27/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.4017 - accuracy: 0.9388 - val_loss: 0.6535 - val_accuracy: 0.8771
# Epoch 28/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.3996 - accuracy: 0.9382 - val_loss: 0.7282 - val_accuracy: 0.8563
# Epoch 29/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.4008 - accuracy: 0.9390 - val_loss: 1.1759 - val_accuracy: 0.7555
# Epoch 30/30
# 391/391 [==============================] - 139s 355ms/step - loss: 0.3961 - accuracy: 0.9406 - val_loss: 0.7719 - val_accuracy: 0.8477
